# %% [markdown]
# Q1: Who developed Python Programming Language?
# Ans: Guido van Rossum.

# %% [markdown]
# Q2: Which type of programming does python support?
# Ans: Python supports four main programming paradigms: imperative, functional, procedural, and object-oriented

# %% [markdown]
# Q3: Is Python case sensitive when dealing with identifiers?
# Ans: Yes, Python is a case-sensitive language,

# %% [markdown]
# Q4: What is the correct extension of Python file?
# Ans:  .py

# %% [markdown]
# Q5: Is Python code is compiled or interpreted?
# Ans: interpreted language.

# %% [markdown]
# Q6: Name a few blocks of code use to define in Python language?
# Ans:  a module, a function body, and a class definition.

# %% [markdown]
# Q7: State a character used to give single line comments in Python?
# Ans: # Statement.

# %% [markdown]
# Q8: Mention function which can help us to find the version of python that
# we are currently working on?
# Ans: function sys.version.

# %% [markdown]
# Q9:What does PIP stand for Python?
# Ans: preferred installer program.

# %% [markdown]
# Q10: Mention few built in function in python?
# Ans: Python Built-in Functions:
# print( ) function.
# type( ) function.
# input( ) function.
# abs( ) function.
# pow( ) function.
# dir( ) function.
# sorted( ) function.
# max( ) function.

# %% [markdown]
# Q11: What is maximum possible length of an identifier in Python?
# Ans: 79 characters.

# %% [markdown]
# Q12: What are the benefits of using Python?
# Ans:Top Reasons to Learn Python:
# Data science.
# Scientific and mathematical computing.
# Web development.
# Finance and trading.
# System automation and administration.
# Computer graphics.
# Basic game development.
# Security and penetration testing.
